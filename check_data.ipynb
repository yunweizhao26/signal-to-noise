# %%
from pathlib import Path
import importlib
import os
import numpy as np
from anndata import read_h5ad
#from scipy.sparse import dok_matrix
import json
from operator import itemgetter

# %%
files = list(Path("./datasets").glob("*.h5ad"))

def check_mem_usage():
    import psutil
    import os
    
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    print(f"Current memory usage: {memory_info.rss / (1024 * 1024):.2f} MB")

def force_gc():
    import gc
    check_mem_usage()
    print(f"collecting {gc.collect()} objects")
    check_mem_usage()

for f in files:
    print(f"Processing dataset {f.stem}")
    adata = read_h5ad(f)
    
    # filter out cells that originate from other datasets
    adata = adata[adata.obs["is_primary_data"] == True]
    
    dataset_id = f.stem
    
    metadata_markers = adata.obs[["disease", "tissue"]].drop_duplicates()
    
    analysis_data = {}
    analysis_data_path = os.path.join("output", "analysis", dataset_id + ".json")
    if os.path.exists(analysis_data_path):
        with open(analysis_data_path, "r") as in_f:
            analysis_data = json.load(in_f)
    
    else:
        os.makedirs(os.path.dirname(analysis_data_path), exist_ok=True)
    
    # assume that the imputation methods were all run correctly and the subset results are present, splitting
    i = 0
    for _, (disease, tissue) in metadata_markers.iterrows():
        i += 1
        print(f"Analyzing sample {i}/{len(metadata_markers)}: {tissue} ({disease})")
        
        mask = (adata.obs["disease"] == disease) & (adata.obs["tissue"] == tissue)
        adata_sample = adata[mask]
        input = adata_sample.X.toarray()
        print(f"- Sample matrix has shape {input.shape}")
        # `sample_analysis` refers to data about the entire sample
        sample_analysis = analysis_data.setdefault(f"{disease}, {tissue}", {})
        sample_analysis["shape"] = input.shape
        print("adata_sample.obs: ", adata_sample.obs)
        # print("adata_sample.obs_keys(): ", adata_sample.obs_keys())
        # print("adata_sample.var_keys(): ", adata_sample.var_keys())
        # print("adata_sample.obs.columns: ", adata_sample.obs.columns)
        # print("adata_sample.var.columns: ", adata_sample.var.columns)
        # print("adata_sample.obs.index: ", adata_sample.obs.index)
        # print("adata_sample.var.index: ", adata_sample.var.index)
        # print("adata_sample.obs_names: ", adata_sample.obs_names)
        # print("adata_sample.var_names: ", adata_sample.var_names)
        # print("adata_sample.obs.index.values: ", adata_sample.obs.index.values)
        print("adata_sample.var[feature_name]: ", adata_sample.var["feature_name"])
        print("adata_sample.obs[Celltype]: ", adata_sample.obs.index)
        # print("adata_sample.var.index.values: ", adata_sample.var.index.values)
    
        # prematurely dump the json after testing every sample for easy monitoring
        with open(analysis_data_path, "w") as out_f:
            json.dump(analysis_data, out_f, indent=4)
            
        force_gc()
        print("")
# Out:
# Processing dataset 63ff2c52-cb63-44f0-bac3-d0b33373e312
# Analyzing sample 1/9: lamina propria of mucosa of colon (Crohn disease)
# - Sample matrix has shape (8076, 27289)
# adata_sample.obs:                             biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG    N105446_L   2205.0   76317.0  NonI   105446
# N105446_L-TCGACGGGTGAGACCA    N105446_L   2088.0   67801.0  NonI   105446
# N105446_L-AGTAACCGTTAAGGGC    N105446_L   1862.0   58097.0  NonI   105446
# N105446_L-GCAGGCTTCGCTAAAC    N105446_L   5472.0   43418.0  NonI   105446
# N105446_L-ATCTTCATCTGAGAGG    N105446_L   5650.0   42871.0  NonI   105446
# ...                                 ...      ...       ...   ...      ...
# N130084_L-GTGGTTACAGTTCCAA    N130084_L    305.0     488.0  NonI   130084
# N130084_L-TATCCTATCGTTCATT    N130084_L    294.0     490.0  NonI   130084
# N130084_L-TCATCCGGTATGATCC    N130084_L    268.0     453.0  NonI   130084
# N130084_L-GGTCACGGTTAGCGGA    N130084_L    289.0     442.0  NonI   130084
# N130084_L-TGGTGATAGTTGGAAT    N130084_L    224.0     344.0  NonI   130084
#
#                            Layer                  Celltype  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG     L              Paneth cells
# N105446_L-TCGACGGGTGAGACCA     L              Paneth cells
# N105446_L-AGTAACCGTTAAGGGC     L              Paneth cells
# N105446_L-GCAGGCTTCGCTAAAC     L    Goblet cells MUC2 TFF1
# N105446_L-ATCTTCATCTGAGAGG     L   Goblet cells MUC2 TFF1-
# ...                          ...                       ...
# N130084_L-GTGGTTACAGTTCCAA     L                Tuft cells
# N130084_L-TATCCTATCGTTCATT     L  Enterocytes CA1 CA2 CA4-
# N130084_L-TCATCCGGTATGATCC     L         Enterocytes BEST4
# N130084_L-GGTCACGGTTAGCGGA     L  Enterocytes CA1 CA2 CA4-
# N130084_L-TGGTGATAGTTGGAAT     L  Enterocytes CA1 CA2 CA4-
#
#                            organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG            NCBITaxon:9606            EFO:0009922
# N105446_L-TCGACGGGTGAGACCA            NCBITaxon:9606            EFO:0009922
# N105446_L-AGTAACCGTTAAGGGC            NCBITaxon:9606            EFO:0009922
# N105446_L-GCAGGCTTCGCTAAAC            NCBITaxon:9606            EFO:0009922
# N105446_L-ATCTTCATCTGAGAGG            NCBITaxon:9606            EFO:0009922
# ...                                              ...                    ...
# N130084_L-GTGGTTACAGTTCCAA            NCBITaxon:9606            EFO:0009922
# N130084_L-TATCCTATCGTTCATT            NCBITaxon:9606            EFO:0009922
# N130084_L-TCATCCGGTATGATCC            NCBITaxon:9606            EFO:0009922
# N130084_L-GGTCACGGTTAGCGGA            NCBITaxon:9606            EFO:0009922
# N130084_L-TGGTGATAGTTGGAAT            NCBITaxon:9606            EFO:0009922
#
#                            disease_ontology_term_id  ... tissue_type  \
# cell_id                                              ...
# N105446_L-ATTGTTCCAAACGTGG            MONDO:0005011  ...      tissue
# N105446_L-TCGACGGGTGAGACCA            MONDO:0005011  ...      tissue
# N105446_L-AGTAACCGTTAAGGGC            MONDO:0005011  ...      tissue
# N105446_L-GCAGGCTTCGCTAAAC            MONDO:0005011  ...      tissue
# N105446_L-ATCTTCATCTGAGAGG            MONDO:0005011  ...      tissue
# ...                                             ...  ...         ...
# N130084_L-GTGGTTACAGTTCCAA            MONDO:0005011  ...      tissue
# N130084_L-TATCCTATCGTTCATT            MONDO:0005011  ...      tissue
# N130084_L-TCATCCGGTATGATCC            MONDO:0005011  ...      tissue
# N130084_L-GGTCACGGTTAGCGGA            MONDO:0005011  ...      tissue
# N130084_L-TGGTGATAGTTGGAAT            MONDO:0005011  ...      tissue
#
#                               cell_type      assay        disease  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG  paneth cell  10x 3' v3  Crohn disease
# N105446_L-TCGACGGGTGAGACCA  paneth cell  10x 3' v3  Crohn disease
# N105446_L-AGTAACCGTTAAGGGC  paneth cell  10x 3' v3  Crohn disease
# N105446_L-GCAGGCTTCGCTAAAC  goblet cell  10x 3' v3  Crohn disease
# N105446_L-ATCTTCATCTGAGAGG  goblet cell  10x 3' v3  Crohn disease
# ...                                 ...        ...            ...
# N130084_L-GTGGTTACAGTTCCAA   brush cell  10x 3' v3  Crohn disease
# N130084_L-TATCCTATCGTTCATT   enterocyte  10x 3' v3  Crohn disease
# N130084_L-TCATCCGGTATGATCC   enterocyte  10x 3' v3  Crohn disease
# N130084_L-GGTCACGGTTAGCGGA   enterocyte  10x 3' v3  Crohn disease
# N130084_L-TGGTGATAGTTGGAAT   enterocyte  10x 3' v3  Crohn disease
#
#                                 organism     sex  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG  Homo sapiens    male
# N105446_L-TCGACGGGTGAGACCA  Homo sapiens    male
# N105446_L-AGTAACCGTTAAGGGC  Homo sapiens    male
# N105446_L-GCAGGCTTCGCTAAAC  Homo sapiens    male
# N105446_L-ATCTTCATCTGAGAGG  Homo sapiens    male
# ...                                  ...     ...
# N130084_L-GTGGTTACAGTTCCAA  Homo sapiens  female
# N130084_L-TATCCTATCGTTCATT  Homo sapiens  female
# N130084_L-TCATCCGGTATGATCC  Homo sapiens  female
# N130084_L-GGTCACGGTTAGCGGA  Homo sapiens  female
# N130084_L-TGGTGATAGTTGGAAT  Homo sapiens  female
#
#                                                        tissue  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG  lamina propria of mucosa of colon
# N105446_L-TCGACGGGTGAGACCA  lamina propria of mucosa of colon
# N105446_L-AGTAACCGTTAAGGGC  lamina propria of mucosa of colon
# N105446_L-GCAGGCTTCGCTAAAC  lamina propria of mucosa of colon
# N105446_L-ATCTTCATCTGAGAGG  lamina propria of mucosa of colon
# ...                                                       ...
# N130084_L-GTGGTTACAGTTCCAA  lamina propria of mucosa of colon
# N130084_L-TATCCTATCGTTCATT  lamina propria of mucosa of colon
# N130084_L-TCATCCGGTATGATCC  lamina propria of mucosa of colon
# N130084_L-GGTCACGGTTAGCGGA  lamina propria of mucosa of colon
# N130084_L-TGGTGATAGTTGGAAT  lamina propria of mucosa of colon
#
#                            self_reported_ethnicity   development_stage  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG                 unknown  third decade stage
# N105446_L-TCGACGGGTGAGACCA                 unknown  third decade stage
# N105446_L-AGTAACCGTTAAGGGC                 unknown  third decade stage
# N105446_L-GCAGGCTTCGCTAAAC                 unknown  third decade stage
# N105446_L-ATCTTCATCTGAGAGG                 unknown  third decade stage
# ...                                            ...                 ...
# N130084_L-GTGGTTACAGTTCCAA                 unknown  fifth decade stage
# N130084_L-TATCCTATCGTTCATT                 unknown  fifth decade stage
# N130084_L-TCATCCGGTATGATCC                 unknown  fifth decade stage
# N130084_L-GGTCACGGTTAGCGGA                 unknown  fifth decade stage
# N130084_L-TGGTGATAGTTGGAAT                 unknown  fifth decade stage
#
#                            observation_joinid
# cell_id
# N105446_L-ATTGTTCCAAACGTGG         w97P9k|zH%
# N105446_L-TCGACGGGTGAGACCA         Rb6Q)N`<2R
# N105446_L-AGTAACCGTTAAGGGC         U#f<|IH<Qf
# N105446_L-GCAGGCTTCGCTAAAC         v5a!xe$<@8
# N105446_L-ATCTTCATCTGAGAGG         )sT}^bxtV-
# ...                                       ...
# N130084_L-GTGGTTACAGTTCCAA         5KJ!=p7|I#
# N130084_L-TATCCTATCGTTCATT         p*+)_8LHHP
# N130084_L-TCATCCGGTATGATCC         OIjbT?6L&R
# N130084_L-GGTCACGGTTAGCGGA         4hrg9>_1UP
# N130084_L-TGGTGATAGTTGGAAT         xDBqUb^ns|
#
# [8076 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['N105446_L-ATTGTTCCAAACGTGG', 'N105446_L-TCGACGGGTGAGACCA',
#        'N105446_L-AGTAACCGTTAAGGGC', 'N105446_L-GCAGGCTTCGCTAAAC',
#        'N105446_L-ATCTTCATCTGAGAGG', 'N105446_L-ATTTACCTCGATACAC',
#        'N105446_L-GCCATGGTCGAGAAGC', 'N105446_L-GTTCCGTCACAATGTC',
#        'N105446_L-GAGACTTGTGCTTCAA', 'N105446_L-CGCATAAAGTGCGACA',
#        ...
#        'N130084_L-GTTCTATTCGTTCGCT', 'N130084_L-CGCATAAGTGCCGGTT',
#        'N130084_L-ATTCAGGAGCCAGAGT', 'N130084_L-AGGCCACGTATACAGA',
#        'N130084_L-CTCATGCAGTAGGCCA', 'N130084_L-GTGGTTACAGTTCCAA',
#        'N130084_L-TATCCTATCGTTCATT', 'N130084_L-TCATCCGGTATGATCC',
#        'N130084_L-GGTCACGGTTAGCGGA', 'N130084_L-TGGTGATAGTTGGAAT'],
#       dtype='object', name='cell_id', length=8076)
# Current memory usage: 7770.86 MB
# collecting 1577 objects
# Current memory usage: 7676.73 MB
#
# Analyzing sample 2/9: colonic epithelium (Crohn disease)
# - Sample matrix has shape (17553, 27289)
# adata_sample.obs:                             biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# N110204_E-GAAGTAATCGATACTG    N110204_E   5883.0   66484.0  NonI   110204
# N110204_E-TGTAACGAGCATAGGC    N110204_E   5507.0   41430.0  NonI   110204
# N110204_E-TCATACTGTTCCTACC    N110204_E   4893.0   40018.0  NonI   110204
# N110204_E-ATTGGGTGTCACTAGT    N110204_E   5420.0   37487.0  NonI   110204
# N110204_E-AAGAACAAGCATCAAA    N110204_E   5552.0   37121.0  NonI   110204
# ...                                 ...      ...       ...   ...      ...
# N130084_E-GATGATCAGTCATGGG    N130084_E    303.0     449.0  NonI   130084
# N130084_E-ATCCACCTCACATACG    N130084_E    209.0     379.0  NonI   130084
# N130084_E-GGGTTATTCCTGGGAC    N130084_E    332.0     520.0  NonI   130084
# N130084_E-AAGTACCTCGCGTGAC    N130084_E    217.0     359.0  NonI   130084
# N130084_E-CATTCATTCGGTCGAC    N130084_E    280.0     394.0  NonI   130084
#
#                            Layer                  Celltype  \
# cell_id
# N110204_E-GAAGTAATCGATACTG     E         Enterocytes BEST4
# N110204_E-TGTAACGAGCATAGGC     E  Epithelial Cycling cells
# N110204_E-TCATACTGTTCCTACC     E  Enterocytes CA1 CA2 CA4-
# N110204_E-ATTGGGTGTCACTAGT     E  Epithelial Cycling cells
# N110204_E-AAGAACAAGCATCAAA     E  Enterocytes CA1 CA2 CA4-
# ...                          ...                       ...
# N130084_E-GATGATCAGTCATGGG     E  Enterocytes CA1 CA2 CA4-
# N130084_E-ATCCACCTCACATACG     E  Enterocytes CA1 CA2 CA4-
# N130084_E-GGGTTATTCCTGGGAC     E       Goblet cells SPINK4
# N130084_E-AAGTACCTCGCGTGAC     E  Enterocytes CA1 CA2 CA4-
# N130084_E-CATTCATTCGGTCGAC     E  Enterocytes CA1 CA2 CA4-
#
#                            organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# N110204_E-GAAGTAATCGATACTG            NCBITaxon:9606            EFO:0009922
# N110204_E-TGTAACGAGCATAGGC            NCBITaxon:9606            EFO:0009922
# N110204_E-TCATACTGTTCCTACC            NCBITaxon:9606            EFO:0009922
# N110204_E-ATTGGGTGTCACTAGT            NCBITaxon:9606            EFO:0009922
# N110204_E-AAGAACAAGCATCAAA            NCBITaxon:9606            EFO:0009922
# ...                                              ...                    ...
# N130084_E-GATGATCAGTCATGGG            NCBITaxon:9606            EFO:0009922
# N130084_E-ATCCACCTCACATACG            NCBITaxon:9606            EFO:0009922
# N130084_E-GGGTTATTCCTGGGAC            NCBITaxon:9606            EFO:0009922
# N130084_E-AAGTACCTCGCGTGAC            NCBITaxon:9606            EFO:0009922
# N130084_E-CATTCATTCGGTCGAC            NCBITaxon:9606            EFO:0009922
#
#                            disease_ontology_term_id  ... tissue_type  \
# cell_id                                              ...
# N110204_E-GAAGTAATCGATACTG            MONDO:0005011  ...      tissue
# N110204_E-TGTAACGAGCATAGGC            MONDO:0005011  ...      tissue
# N110204_E-TCATACTGTTCCTACC            MONDO:0005011  ...      tissue
# N110204_E-ATTGGGTGTCACTAGT            MONDO:0005011  ...      tissue
# N110204_E-AAGAACAAGCATCAAA            MONDO:0005011  ...      tissue
# ...                                             ...  ...         ...
# N130084_E-GATGATCAGTCATGGG            MONDO:0005011  ...      tissue
# N130084_E-ATCCACCTCACATACG            MONDO:0005011  ...      tissue
# N130084_E-GGGTTATTCCTGGGAC            MONDO:0005011  ...      tissue
# N130084_E-AAGTACCTCGCGTGAC            MONDO:0005011  ...      tissue
# N130084_E-CATTCATTCGGTCGAC            MONDO:0005011  ...      tissue
#
#                                   cell_type      assay        disease  \
# cell_id
# N110204_E-GAAGTAATCGATACTG       enterocyte  10x 3' v3  Crohn disease
# N110204_E-TGTAACGAGCATAGGC  epithelial cell  10x 3' v3  Crohn disease
# N110204_E-TCATACTGTTCCTACC       enterocyte  10x 3' v3  Crohn disease
# N110204_E-ATTGGGTGTCACTAGT  epithelial cell  10x 3' v3  Crohn disease
# N110204_E-AAGAACAAGCATCAAA       enterocyte  10x 3' v3  Crohn disease
# ...                                     ...        ...            ...
# N130084_E-GATGATCAGTCATGGG       enterocyte  10x 3' v3  Crohn disease
# N130084_E-ATCCACCTCACATACG       enterocyte  10x 3' v3  Crohn disease
# N130084_E-GGGTTATTCCTGGGAC      goblet cell  10x 3' v3  Crohn disease
# N130084_E-AAGTACCTCGCGTGAC       enterocyte  10x 3' v3  Crohn disease
# N130084_E-CATTCATTCGGTCGAC       enterocyte  10x 3' v3  Crohn disease
#
#                                 organism     sex              tissue  \
# cell_id
# N110204_E-GAAGTAATCGATACTG  Homo sapiens    male  colonic epithelium
# N110204_E-TGTAACGAGCATAGGC  Homo sapiens    male  colonic epithelium
# N110204_E-TCATACTGTTCCTACC  Homo sapiens    male  colonic epithelium
# N110204_E-ATTGGGTGTCACTAGT  Homo sapiens    male  colonic epithelium
# N110204_E-AAGAACAAGCATCAAA  Homo sapiens    male  colonic epithelium
# ...                                  ...     ...                 ...
# N130084_E-GATGATCAGTCATGGG  Homo sapiens  female  colonic epithelium
# N130084_E-ATCCACCTCACATACG  Homo sapiens  female  colonic epithelium
# N130084_E-GGGTTATTCCTGGGAC  Homo sapiens  female  colonic epithelium
# N130084_E-AAGTACCTCGCGTGAC  Homo sapiens  female  colonic epithelium
# N130084_E-CATTCATTCGGTCGAC  Homo sapiens  female  colonic epithelium
#
#                            self_reported_ethnicity   development_stage  \
# cell_id
# N110204_E-GAAGTAATCGATACTG                 unknown  third decade stage
# N110204_E-TGTAACGAGCATAGGC                 unknown  third decade stage
# N110204_E-TCATACTGTTCCTACC                 unknown  third decade stage
# N110204_E-ATTGGGTGTCACTAGT                 unknown  third decade stage
# N110204_E-AAGAACAAGCATCAAA                 unknown  third decade stage
# ...                                            ...                 ...
# N130084_E-GATGATCAGTCATGGG                 unknown  fifth decade stage
# N130084_E-ATCCACCTCACATACG                 unknown  fifth decade stage
# N130084_E-GGGTTATTCCTGGGAC                 unknown  fifth decade stage
# N130084_E-AAGTACCTCGCGTGAC                 unknown  fifth decade stage
# N130084_E-CATTCATTCGGTCGAC                 unknown  fifth decade stage
#
#                            observation_joinid
# cell_id
# N110204_E-GAAGTAATCGATACTG         ?SUI!9p1yn
# N110204_E-TGTAACGAGCATAGGC         V+p|twUvDH
# N110204_E-TCATACTGTTCCTACC         nm3Ky3m|6?
# N110204_E-ATTGGGTGTCACTAGT         DmxmjHcY;u
# N110204_E-AAGAACAAGCATCAAA         L25cdU$y$L
# ...                                       ...
# N130084_E-GATGATCAGTCATGGG         AZK@5JfqIs
# N130084_E-ATCCACCTCACATACG         X@M4T)xj})
# N130084_E-GGGTTATTCCTGGGAC         +zwpA-rh(z
# N130084_E-AAGTACCTCGCGTGAC         !6IQL5Smuc
# N130084_E-CATTCATTCGGTCGAC         hP%7n|62JG
#
# [17553 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['N110204_E-GAAGTAATCGATACTG', 'N110204_E-TGTAACGAGCATAGGC',
#        'N110204_E-TCATACTGTTCCTACC', 'N110204_E-ATTGGGTGTCACTAGT',
#        'N110204_E-AAGAACAAGCATCAAA', 'N110204_E-TGCTTGCTCCTTCAGC',
#        'N110204_E-GAAATGAGTAACACCT', 'N110204_E-AACCTTTGTATCCTTT',
#        'N110204_E-GTGGAGATCCCTGGTT', 'N110204_E-GTGAGGATCAACCCGG',
#        ...
#        'N130084_E-TTTGGTTCAGGCCCTA', 'N130084_E-TCGGTCTCAACCAATC',
#        'N130084_E-AGAGCAGAGGTTCAGG', 'N130084_E-TTGCATTTCTACGGGC',
#        'N130084_E-GTAATGCAGCCTCCAG', 'N130084_E-GATGATCAGTCATGGG',
#        'N130084_E-ATCCACCTCACATACG', 'N130084_E-GGGTTATTCCTGGGAC',
#        'N130084_E-AAGTACCTCGCGTGAC', 'N130084_E-CATTCATTCGGTCGAC'],
#       dtype='object', name='cell_id', length=17553)
# Current memory usage: 8619.43 MB
# collecting 583 objects
# Current memory usage: 8474.98 MB
#
# Analyzing sample 3/9: colon (normal)
# - Sample matrix has shape (14591, 27289)
# adata_sample.obs:                              biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# H197396_N1-GCTTGAAGTCATGCCG   H197396_N1   4319.0   25850.0  Heal   197396
# H197396_N1-AGGGAGTCACCTTGTC   H197396_N1   3892.0   21899.0  Heal   197396
# H197396_N1-CATATTCAGGGAGTAA   H197396_N1   3772.0   20100.0  Heal   197396
# H197396_N1-CGCTTCAAGGCTACGA   H197396_N1   3540.0   19798.0  Heal   197396
# H197396_N1-CGGAGTCGTGAGTGAC   H197396_N1   3384.0   18693.0  Heal   197396
# ...                                  ...      ...       ...   ...      ...
# H106265_N-CGTTGGGCACCGATAT     H106265_N    202.0     304.0  Heal   106265
# H106265_N-CTGCCTACACCAGCAC     H106265_N    210.0     307.0  Heal   106265
# H106265_N-GCACATAAGAGACTAT     H106265_N    203.0     270.0  Heal   106265
# H106265_N-CACAAACTCCACGTTC     H106265_N    201.0     269.0  Heal   106265
# H106265_N-AGAGCGAAGAGAGCTC     H106265_N    214.0     289.0  Heal   106265
#
#                             Layer                  Celltype  \
# cell_id
# H197396_N1-GCTTGAAGTCATGCCG     N  Enterocytes CA1 CA2 CA4-
# H197396_N1-AGGGAGTCACCTTGTC     N  Enterocytes CA1 CA2 CA4-
# H197396_N1-CATATTCAGGGAGTAA     N  Enterocytes TMIGD1 MEP1A
# H197396_N1-CGCTTCAAGGCTACGA     N  Enterocytes CA1 CA2 CA4-
# H197396_N1-CGGAGTCGTGAGTGAC     N   Goblet cells MUC2 TFF1-
# ...                           ...                       ...
# H106265_N-CGTTGGGCACCGATAT      N  Enterocytes CA1 CA2 CA4-
# H106265_N-CTGCCTACACCAGCAC      N  Enterocytes CA1 CA2 CA4-
# H106265_N-GCACATAAGAGACTAT      N  Enterocytes CA1 CA2 CA4-
# H106265_N-CACAAACTCCACGTTC      N  Enterocytes CA1 CA2 CA4-
# H106265_N-AGAGCGAAGAGAGCTC      N  Epithelial Cycling cells
#
#                             organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# H197396_N1-GCTTGAAGTCATGCCG            NCBITaxon:9606            EFO:0009899
# H197396_N1-AGGGAGTCACCTTGTC            NCBITaxon:9606            EFO:0009899
# H197396_N1-CATATTCAGGGAGTAA            NCBITaxon:9606            EFO:0009899
# H197396_N1-CGCTTCAAGGCTACGA            NCBITaxon:9606            EFO:0009899
# H197396_N1-CGGAGTCGTGAGTGAC            NCBITaxon:9606            EFO:0009899
# ...                                               ...                    ...
# H106265_N-CGTTGGGCACCGATAT             NCBITaxon:9606            EFO:0009899
# H106265_N-CTGCCTACACCAGCAC             NCBITaxon:9606            EFO:0009899
# H106265_N-GCACATAAGAGACTAT             NCBITaxon:9606            EFO:0009899
# H106265_N-CACAAACTCCACGTTC             NCBITaxon:9606            EFO:0009899
# H106265_N-AGAGCGAAGAGAGCTC             NCBITaxon:9606            EFO:0009899
#
#                             disease_ontology_term_id  ... tissue_type  \
# cell_id                                               ...
# H197396_N1-GCTTGAAGTCATGCCG             PATO:0000461  ...      tissue
# H197396_N1-AGGGAGTCACCTTGTC             PATO:0000461  ...      tissue
# H197396_N1-CATATTCAGGGAGTAA             PATO:0000461  ...      tissue
# H197396_N1-CGCTTCAAGGCTACGA             PATO:0000461  ...      tissue
# H197396_N1-CGGAGTCGTGAGTGAC             PATO:0000461  ...      tissue
# ...                                              ...  ...         ...
# H106265_N-CGTTGGGCACCGATAT              PATO:0000461  ...      tissue
# H106265_N-CTGCCTACACCAGCAC              PATO:0000461  ...      tissue
# H106265_N-GCACATAAGAGACTAT              PATO:0000461  ...      tissue
# H106265_N-CACAAACTCCACGTTC              PATO:0000461  ...      tissue
# H106265_N-AGAGCGAAGAGAGCTC              PATO:0000461  ...      tissue
#
#                                    cell_type      assay disease      organism  \
# cell_id
# H197396_N1-GCTTGAAGTCATGCCG       enterocyte  10x 3' v2  normal  Homo sapiens
# H197396_N1-AGGGAGTCACCTTGTC       enterocyte  10x 3' v2  normal  Homo sapiens
# H197396_N1-CATATTCAGGGAGTAA       enterocyte  10x 3' v2  normal  Homo sapiens
# H197396_N1-CGCTTCAAGGCTACGA       enterocyte  10x 3' v2  normal  Homo sapiens
# H197396_N1-CGGAGTCGTGAGTGAC      goblet cell  10x 3' v2  normal  Homo sapiens
# ...                                      ...        ...     ...           ...
# H106265_N-CGTTGGGCACCGATAT        enterocyte  10x 3' v2  normal  Homo sapiens
# H106265_N-CTGCCTACACCAGCAC        enterocyte  10x 3' v2  normal  Homo sapiens
# H106265_N-GCACATAAGAGACTAT        enterocyte  10x 3' v2  normal  Homo sapiens
# H106265_N-CACAAACTCCACGTTC        enterocyte  10x 3' v2  normal  Homo sapiens
# H106265_N-AGAGCGAAGAGAGCTC   epithelial cell  10x 3' v2  normal  Homo sapiens
#
#                                 sex tissue self_reported_ethnicity  \
# cell_id
# H197396_N1-GCTTGAAGTCATGCCG    male  colon                 unknown
# H197396_N1-AGGGAGTCACCTTGTC    male  colon                 unknown
# H197396_N1-CATATTCAGGGAGTAA    male  colon                 unknown
# H197396_N1-CGCTTCAAGGCTACGA    male  colon                 unknown
# H197396_N1-CGGAGTCGTGAGTGAC    male  colon                 unknown
# ...                             ...    ...                     ...
# H106265_N-CGTTGGGCACCGATAT   female  colon                 unknown
# H106265_N-CTGCCTACACCAGCAC   female  colon                 unknown
# H106265_N-GCACATAAGAGACTAT   female  colon                 unknown
# H106265_N-CACAAACTCCACGTTC   female  colon                 unknown
# H106265_N-AGAGCGAAGAGAGCTC   female  colon                 unknown
#
#                                development_stage observation_joinid
# cell_id
# H197396_N1-GCTTGAAGTCATGCCG  eighth decade stage         yr!bXRByuE
# H197396_N1-AGGGAGTCACCTTGTC  eighth decade stage         3*44<J(xx4
# H197396_N1-CATATTCAGGGAGTAA  eighth decade stage         fzV=l*QmCY
# H197396_N1-CGCTTCAAGGCTACGA  eighth decade stage         1*c(E`K_%l
# H197396_N1-CGGAGTCGTGAGTGAC  eighth decade stage         re;RS%#ZWO
# ...                                          ...                ...
# H106265_N-CGTTGGGCACCGATAT    third decade stage         1Q@TBl757=
# H106265_N-CTGCCTACACCAGCAC    third decade stage         K^9sNW9`vX
# H106265_N-GCACATAAGAGACTAT    third decade stage         XZ^mR0#w)h
# H106265_N-CACAAACTCCACGTTC    third decade stage         waTt8t3%j<
# H106265_N-AGAGCGAAGAGAGCTC    third decade stage         =FWzH18&ps
#
# [14591 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['H197396_N1-GCTTGAAGTCATGCCG', 'H197396_N1-AGGGAGTCACCTTGTC',
#        'H197396_N1-CATATTCAGGGAGTAA', 'H197396_N1-CGCTTCAAGGCTACGA',
#        'H197396_N1-CGGAGTCGTGAGTGAC', 'H197396_N1-GCAGCCAAGGCTCATT',
#        'H197396_N1-TGGCCAGAGCTCCTCT', 'H197396_N1-AGAATAGGTGTCAATC',
#        'H197396_N1-GAACCTATCATACGGT', 'H197396_N1-ATAGACCAGTACGACG',
#        ...
#        'H106265_N-TTGCGTCGTCAAAGAT', 'H106265_N-GTCATTTCATACGCCG',
#        'H106265_N-GGGATGAAGACCTTTG', 'H106265_N-CATATGGTCGACGGAA',
#        'H106265_N-TACGGATTCATCGATG', 'H106265_N-CGTTGGGCACCGATAT',
#        'H106265_N-CTGCCTACACCAGCAC', 'H106265_N-GCACATAAGAGACTAT',
#        'H106265_N-CACAAACTCCACGTTC', 'H106265_N-AGAGCGAAGAGAGCTC'],
#       dtype='object', name='cell_id', length=14591)
# Current memory usage: 8327.80 MB
# collecting 583 objects
# Current memory usage: 8154.98 MB
#
# Analyzing sample 4/9: sigmoid colon (Crohn disease)
# - Sample matrix has shape (5385, 27289)
# adata_sample.obs:                              biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG   I175041_N1   5665.0   58383.0  Infl   175041
# I175041_N1-AAGGCAGGTTACTGAC   I175041_N1   5979.0   57637.0  Infl   175041
# I175041_N1-GCATGATGTTCGTTGA   I175041_N1   5546.0   50517.0  Infl   175041
# I175041_N1-CCCATACCAGTACACT   I175041_N1   5296.0   50327.0  Infl   175041
# I175041_N1-ACGCCGAGTCCCTTGT   I175041_N1   5931.0   49778.0  Infl   175041
# ...                                  ...      ...       ...   ...      ...
# I130084_L-TATTGGGGTCTTTATC     I130084_L    200.0     267.0  Infl   130084
# I130084_L-GATGAGGTCAGACAAA     I130084_L    209.0     266.0  Infl   130084
# I130084_L-CACAGATGTAGAGGAA     I130084_L    203.0     255.0  Infl   130084
# I130084_L-GGCTTTCGTTGCCATA     I130084_L    201.0     241.0  Infl   130084
# I130084_L-CTCCATGCACAATGCT     I130084_L    201.0     242.0  Infl   130084
#
#                             Layer                  Celltype  \
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG     N  Enterocytes TMIGD1 MEP1A
# I175041_N1-AAGGCAGGTTACTGAC     N  Enterocytes CA1 CA2 CA4-
# I175041_N1-GCATGATGTTCGTTGA     N  Enterocytes CA1 CA2 CA4-
# I175041_N1-CCCATACCAGTACACT     N  Enterocytes CA1 CA2 CA4-
# I175041_N1-ACGCCGAGTCCCTTGT     N  Enterocytes CA1 CA2 CA4-
# ...                           ...                       ...
# I130084_L-TATTGGGGTCTTTATC      L  Enterocytes CA1 CA2 CA4-
# I130084_L-GATGAGGTCAGACAAA      L  Enterocytes CA1 CA2 CA4-
# I130084_L-CACAGATGTAGAGGAA      L  Enterocytes CA1 CA2 CA4-
# I130084_L-GGCTTTCGTTGCCATA      L  Enterocytes CA1 CA2 CA4-
# I130084_L-CTCCATGCACAATGCT      L  Enterocytes CA1 CA2 CA4-
#
#                             organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG            NCBITaxon:9606            EFO:0009899
# I175041_N1-AAGGCAGGTTACTGAC            NCBITaxon:9606            EFO:0009899
# I175041_N1-GCATGATGTTCGTTGA            NCBITaxon:9606            EFO:0009899
# I175041_N1-CCCATACCAGTACACT            NCBITaxon:9606            EFO:0009899
# I175041_N1-ACGCCGAGTCCCTTGT            NCBITaxon:9606            EFO:0009899
# ...                                               ...                    ...
# I130084_L-TATTGGGGTCTTTATC             NCBITaxon:9606            EFO:0009922
# I130084_L-GATGAGGTCAGACAAA             NCBITaxon:9606            EFO:0009922
# I130084_L-CACAGATGTAGAGGAA             NCBITaxon:9606            EFO:0009922
# I130084_L-GGCTTTCGTTGCCATA             NCBITaxon:9606            EFO:0009922
# I130084_L-CTCCATGCACAATGCT             NCBITaxon:9606            EFO:0009922
#
#                             disease_ontology_term_id  ... tissue_type  \
# cell_id                                               ...
# I175041_N1-ACTGAGTTCTCTAAGG            MONDO:0005011  ...      tissue
# I175041_N1-AAGGCAGGTTACTGAC            MONDO:0005011  ...      tissue
# I175041_N1-GCATGATGTTCGTTGA            MONDO:0005011  ...      tissue
# I175041_N1-CCCATACCAGTACACT            MONDO:0005011  ...      tissue
# I175041_N1-ACGCCGAGTCCCTTGT            MONDO:0005011  ...      tissue
# ...                                              ...  ...         ...
# I130084_L-TATTGGGGTCTTTATC             MONDO:0005011  ...      tissue
# I130084_L-GATGAGGTCAGACAAA             MONDO:0005011  ...      tissue
# I130084_L-CACAGATGTAGAGGAA             MONDO:0005011  ...      tissue
# I130084_L-GGCTTTCGTTGCCATA             MONDO:0005011  ...      tissue
# I130084_L-CTCCATGCACAATGCT             MONDO:0005011  ...      tissue
#
#                               cell_type      assay        disease  \
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG  enterocyte  10x 3' v2  Crohn disease
# I175041_N1-AAGGCAGGTTACTGAC  enterocyte  10x 3' v2  Crohn disease
# I175041_N1-GCATGATGTTCGTTGA  enterocyte  10x 3' v2  Crohn disease
# I175041_N1-CCCATACCAGTACACT  enterocyte  10x 3' v2  Crohn disease
# I175041_N1-ACGCCGAGTCCCTTGT  enterocyte  10x 3' v2  Crohn disease
# ...                                 ...        ...            ...
# I130084_L-TATTGGGGTCTTTATC   enterocyte  10x 3' v3  Crohn disease
# I130084_L-GATGAGGTCAGACAAA   enterocyte  10x 3' v3  Crohn disease
# I130084_L-CACAGATGTAGAGGAA   enterocyte  10x 3' v3  Crohn disease
# I130084_L-GGCTTTCGTTGCCATA   enterocyte  10x 3' v3  Crohn disease
# I130084_L-CTCCATGCACAATGCT   enterocyte  10x 3' v3  Crohn disease
#
#                                  organism     sex         tissue  \
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG  Homo sapiens    male  sigmoid colon
# I175041_N1-AAGGCAGGTTACTGAC  Homo sapiens    male  sigmoid colon
# I175041_N1-GCATGATGTTCGTTGA  Homo sapiens    male  sigmoid colon
# I175041_N1-CCCATACCAGTACACT  Homo sapiens    male  sigmoid colon
# I175041_N1-ACGCCGAGTCCCTTGT  Homo sapiens    male  sigmoid colon
# ...                                   ...     ...            ...
# I130084_L-TATTGGGGTCTTTATC   Homo sapiens  female  sigmoid colon
# I130084_L-GATGAGGTCAGACAAA   Homo sapiens  female  sigmoid colon
# I130084_L-CACAGATGTAGAGGAA   Homo sapiens  female  sigmoid colon
# I130084_L-GGCTTTCGTTGCCATA   Homo sapiens  female  sigmoid colon
# I130084_L-CTCCATGCACAATGCT   Homo sapiens  female  sigmoid colon
#
#                             self_reported_ethnicity     development_stage  \
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG                 unknown  seventh decade stage
# I175041_N1-AAGGCAGGTTACTGAC                 unknown  seventh decade stage
# I175041_N1-GCATGATGTTCGTTGA                 unknown  seventh decade stage
# I175041_N1-CCCATACCAGTACACT                 unknown  seventh decade stage
# I175041_N1-ACGCCGAGTCCCTTGT                 unknown  seventh decade stage
# ...                                             ...                   ...
# I130084_L-TATTGGGGTCTTTATC                  unknown    fifth decade stage
# I130084_L-GATGAGGTCAGACAAA                  unknown    fifth decade stage
# I130084_L-CACAGATGTAGAGGAA                  unknown    fifth decade stage
# I130084_L-GGCTTTCGTTGCCATA                  unknown    fifth decade stage
# I130084_L-CTCCATGCACAATGCT                  unknown    fifth decade stage
#
#                             observation_joinid
# cell_id
# I175041_N1-ACTGAGTTCTCTAAGG         {<C=5Bd2$a
# I175041_N1-AAGGCAGGTTACTGAC         V+U#nD@S`(
# I175041_N1-GCATGATGTTCGTTGA         ieok{r5Dt2
# I175041_N1-CCCATACCAGTACACT         R$2Y)o>6qe
# I175041_N1-ACGCCGAGTCCCTTGT         RT?jd3^a!>
# ...                                        ...
# I130084_L-TATTGGGGTCTTTATC          e5CDWMJgd>
# I130084_L-GATGAGGTCAGACAAA          bC8-r`b5As
# I130084_L-CACAGATGTAGAGGAA          wI;f3?Mk39
# I130084_L-GGCTTTCGTTGCCATA          u#bQz+1zBh
# I130084_L-CTCCATGCACAATGCT          F*H*QLz`-3
#
# [5385 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['I175041_N1-ACTGAGTTCTCTAAGG', 'I175041_N1-AAGGCAGGTTACTGAC',
#        'I175041_N1-GCATGATGTTCGTTGA', 'I175041_N1-CCCATACCAGTACACT',
#        'I175041_N1-ACGCCGAGTCCCTTGT', 'I175041_N1-CGGCTAGTCAGAGGTG',
#        'I175041_N1-AACTCTTAGAGAGCTC', 'I175041_N1-TCCACACAGATCTGCT',
#        'I175041_N1-ATCGAGTTCCGCATCT', 'I175041_N1-AACTTTCGTCACCTAA',
#        ...
#        'I130084_L-GGTAGAGCATAGATGA', 'I130084_L-GGTAGAGGTAACGATA',
#        'I130084_L-AGCTTCCTCGCAGAGA', 'I130084_L-ATTCCCGAGCTCCACG',
#        'I130084_L-TACTGCCGTGTCCCTT', 'I130084_L-TATTGGGGTCTTTATC',
#        'I130084_L-GATGAGGTCAGACAAA', 'I130084_L-CACAGATGTAGAGGAA',
#        'I130084_L-GGCTTTCGTTGCCATA', 'I130084_L-CTCCATGCACAATGCT'],
#       dtype='object', name='cell_id', length=5385)
# Current memory usage: 7461.93 MB
# collecting 583 objects
# Current memory usage: 7357.68 MB
#
# Analyzing sample 5/9: colon (Crohn disease)
# - Sample matrix has shape (10929, 27289)
# adata_sample.obs:                             biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# I114902_N-GTTTCTAAGGGTGTTG    I114902_N   5954.0   75547.0  Infl   114902
# I114902_N-CAAGTTGGTATGGTTC    I114902_N   5864.0   70644.0  Infl   114902
# I114902_N-GCAGTTACACAGACAG    I114902_N   5902.0   63895.0  Infl   114902
# I114902_N-GTGCATATCCAGTATG    I114902_N   5991.0   62719.0  Infl   114902
# I114902_N-AGAGTGGAGATCCCGC    I114902_N   5982.0   61366.0  Infl   114902
# ...                                 ...      ...       ...   ...      ...
# N114902_N-CTGCGGACACAGGCCT    N114902_N    202.0     315.0  NonI   114902
# N114902_N-TTGCGTCTCAAAGACA    N114902_N    211.0     274.0  NonI   114902
# N114902_N-TGCGCAGCAACAACCT    N114902_N    222.0     367.0  NonI   114902
# N114902_N-CTAAGACAGATATACG    N114902_N    223.0     321.0  NonI   114902
# N114902_N-AACTCCCCAGCTGCAC    N114902_N    201.0     311.0  NonI   114902
#
#                            Layer                  Celltype  \
# cell_id
# I114902_N-GTTTCTAAGGGTGTTG     N  Enterocytes CA1 CA2 CA4-
# I114902_N-CAAGTTGGTATGGTTC     N     Stem cells OLFM4 LGR5
# I114902_N-GCAGTTACACAGACAG     N     Stem cells OLFM4 LGR5
# I114902_N-GTGCATATCCAGTATG     N  Enterocytes CA1 CA2 CA4-
# I114902_N-AGAGTGGAGATCCCGC     N  Enterocytes TMIGD1 MEP1A
# ...                          ...                       ...
# N114902_N-CTGCGGACACAGGCCT     N  Enterocytes CA1 CA2 CA4-
# N114902_N-TTGCGTCTCAAAGACA     N  Enterocytes CA1 CA2 CA4-
# N114902_N-TGCGCAGCAACAACCT     N  Enterocytes CA1 CA2 CA4-
# N114902_N-CTAAGACAGATATACG     N       Goblet cells SPINK4
# N114902_N-AACTCCCCAGCTGCAC     N       Goblet cells SPINK4
#
#                            organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# I114902_N-GTTTCTAAGGGTGTTG            NCBITaxon:9606            EFO:0009899
# I114902_N-CAAGTTGGTATGGTTC            NCBITaxon:9606            EFO:0009899
# I114902_N-GCAGTTACACAGACAG            NCBITaxon:9606            EFO:0009899
# I114902_N-GTGCATATCCAGTATG            NCBITaxon:9606            EFO:0009899
# I114902_N-AGAGTGGAGATCCCGC            NCBITaxon:9606            EFO:0009899
# ...                                              ...                    ...
# N114902_N-CTGCGGACACAGGCCT            NCBITaxon:9606            EFO:0009899
# N114902_N-TTGCGTCTCAAAGACA            NCBITaxon:9606            EFO:0009899
# N114902_N-TGCGCAGCAACAACCT            NCBITaxon:9606            EFO:0009899
# N114902_N-CTAAGACAGATATACG            NCBITaxon:9606            EFO:0009899
# N114902_N-AACTCCCCAGCTGCAC            NCBITaxon:9606            EFO:0009899
#
#                            disease_ontology_term_id  ... tissue_type  \
# cell_id                                              ...
# I114902_N-GTTTCTAAGGGTGTTG            MONDO:0005011  ...      tissue
# I114902_N-CAAGTTGGTATGGTTC            MONDO:0005011  ...      tissue
# I114902_N-GCAGTTACACAGACAG            MONDO:0005011  ...      tissue
# I114902_N-GTGCATATCCAGTATG            MONDO:0005011  ...      tissue
# I114902_N-AGAGTGGAGATCCCGC            MONDO:0005011  ...      tissue
# ...                                             ...  ...         ...
# N114902_N-CTGCGGACACAGGCCT            MONDO:0005011  ...      tissue
# N114902_N-TTGCGTCTCAAAGACA            MONDO:0005011  ...      tissue
# N114902_N-TGCGCAGCAACAACCT            MONDO:0005011  ...      tissue
# N114902_N-CTAAGACAGATATACG            MONDO:0005011  ...      tissue
# N114902_N-AACTCCCCAGCTGCAC            MONDO:0005011  ...      tissue
#
#                               cell_type      assay        disease  \
# cell_id
# I114902_N-GTTTCTAAGGGTGTTG   enterocyte  10x 3' v2  Crohn disease
# I114902_N-CAAGTTGGTATGGTTC    stem cell  10x 3' v2  Crohn disease
# I114902_N-GCAGTTACACAGACAG    stem cell  10x 3' v2  Crohn disease
# I114902_N-GTGCATATCCAGTATG   enterocyte  10x 3' v2  Crohn disease
# I114902_N-AGAGTGGAGATCCCGC   enterocyte  10x 3' v2  Crohn disease
# ...                                 ...        ...            ...
# N114902_N-CTGCGGACACAGGCCT   enterocyte  10x 3' v2  Crohn disease
# N114902_N-TTGCGTCTCAAAGACA   enterocyte  10x 3' v2  Crohn disease
# N114902_N-TGCGCAGCAACAACCT   enterocyte  10x 3' v2  Crohn disease
# N114902_N-CTAAGACAGATATACG  goblet cell  10x 3' v2  Crohn disease
# N114902_N-AACTCCCCAGCTGCAC  goblet cell  10x 3' v2  Crohn disease
#
#                                 organism   sex tissue self_reported_ethnicity  \
# cell_id
# I114902_N-GTTTCTAAGGGTGTTG  Homo sapiens  male  colon                 unknown
# I114902_N-CAAGTTGGTATGGTTC  Homo sapiens  male  colon                 unknown
# I114902_N-GCAGTTACACAGACAG  Homo sapiens  male  colon                 unknown
# I114902_N-GTGCATATCCAGTATG  Homo sapiens  male  colon                 unknown
# I114902_N-AGAGTGGAGATCCCGC  Homo sapiens  male  colon                 unknown
# ...                                  ...   ...    ...                     ...
# N114902_N-CTGCGGACACAGGCCT  Homo sapiens  male  colon                 unknown
# N114902_N-TTGCGTCTCAAAGACA  Homo sapiens  male  colon                 unknown
# N114902_N-TGCGCAGCAACAACCT  Homo sapiens  male  colon                 unknown
# N114902_N-CTAAGACAGATATACG  Homo sapiens  male  colon                 unknown
# N114902_N-AACTCCCCAGCTGCAC  Homo sapiens  male  colon                 unknown
#
#                               development_stage observation_joinid
# cell_id
# I114902_N-GTTTCTAAGGGTGTTG  fourth decade stage         Y*Tz3u-MB~
# I114902_N-CAAGTTGGTATGGTTC  fourth decade stage         Ch8F#>?tn?
# I114902_N-GCAGTTACACAGACAG  fourth decade stage         V_T{MSfIe-
# I114902_N-GTGCATATCCAGTATG  fourth decade stage         Pj*@|q}FT#
# I114902_N-AGAGTGGAGATCCCGC  fourth decade stage         GTyuu;dgz2
# ...                                         ...                ...
# N114902_N-CTGCGGACACAGGCCT  fourth decade stage         Kdn|}sTOR-
# N114902_N-TTGCGTCTCAAAGACA  fourth decade stage         ZYsrHWpfz2
# N114902_N-TGCGCAGCAACAACCT  fourth decade stage         mb>!o_yMG9
# N114902_N-CTAAGACAGATATACG  fourth decade stage         sMsyQ7y4N<
# N114902_N-AACTCCCCAGCTGCAC  fourth decade stage         L0N_ND7A}j
#
# [10929 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['I114902_N-GTTTCTAAGGGTGTTG', 'I114902_N-CAAGTTGGTATGGTTC',
#        'I114902_N-GCAGTTACACAGACAG', 'I114902_N-GTGCATATCCAGTATG',
#        'I114902_N-AGAGTGGAGATCCCGC', 'I114902_N-CGTAGGCTCCTACAGA',
#        'I114902_N-AACCGCGGTGTAACGG', 'I114902_N-CGTGTCTCATCTGGTA',
#        'I114902_N-TACCTATTCGAGGTAG', 'I114902_N-AACTGGTGTCAAGCGA',
#        ...
#        'N114902_N-GACCTGGCACCGTTGG', 'N114902_N-TCAGGTATCACTATTC',
#        'N114902_N-CTAAGACAGAGGGCTT', 'N114902_N-TTTACTGAGTCATCCA',
#        'N114902_N-GACCTGGTCATAAAGG', 'N114902_N-CTGCGGACACAGGCCT',
#        'N114902_N-TTGCGTCTCAAAGACA', 'N114902_N-TGCGCAGCAACAACCT',
#        'N114902_N-CTAAGACAGATATACG', 'N114902_N-AACTCCCCAGCTGCAC'],
#       dtype='object', name='cell_id', length=10929)
# Current memory usage: 7881.30 MB
# collecting 583 objects
# Current memory usage: 7838.07 MB
#
# Analyzing sample 6/9: left colon (Crohn disease)
# - Sample matrix has shape (6960, 27289)
# adata_sample.obs:                              biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# N175041_N1-ACTTGTTCATTGTGCA   N175041_N1   5568.0   50249.0  NonI   175041
# N175041_N1-TCGAGGCCACGAAAGC   N175041_N1   5628.0   47082.0  NonI   175041
# N175041_N1-CTCCTAGCACATTAGC   N175041_N1   5723.0   45798.0  NonI   175041
# N175041_N1-CTCAGAACACGACGAA   N175041_N1   5333.0   42653.0  NonI   175041
# N175041_N1-CTAGAGTTCACAAACC   N175041_N1   5191.0   41853.0  NonI   175041
# ...                                  ...      ...       ...   ...      ...
# N104152_N-AGCAGCCTCCGAGCCA     N104152_N    222.0     293.0  NonI   104152
# N104152_N-TAGAGCTTCGGGAGTA     N104152_N    201.0     279.0  NonI   104152
# N104152_N-CTCATTAAGATGCCTT     N104152_N    208.0     270.0  NonI   104152
# N104152_N-TGAGAGGTCCACGTTC     N104152_N    205.0     272.0  NonI   104152
# N104152_N-AGGGTGAGTCTCTTTA     N104152_N    209.0     250.0  NonI   104152
#
#                             Layer                  Celltype  \
# cell_id
# N175041_N1-ACTTGTTCATTGTGCA     N  Enterocytes CA1 CA2 CA4-
# N175041_N1-TCGAGGCCACGAAAGC     N  Enterocytes CA1 CA2 CA4-
# N175041_N1-CTCCTAGCACATTAGC     N  Enterocytes CA1 CA2 CA4-
# N175041_N1-CTCAGAACACGACGAA     N  Enterocytes CA1 CA2 CA4-
# N175041_N1-CTAGAGTTCACAAACC     N  Enterocytes CA1 CA2 CA4-
# ...                           ...                       ...
# N104152_N-AGCAGCCTCCGAGCCA      N  Enterocytes CA1 CA2 CA4-
# N104152_N-TAGAGCTTCGGGAGTA      N  Enterocytes CA1 CA2 CA4-
# N104152_N-CTCATTAAGATGCCTT      N       Goblet cells SPINK4
# N104152_N-TGAGAGGTCCACGTTC      N  Enterocytes CA1 CA2 CA4-
# N104152_N-AGGGTGAGTCTCTTTA      N  Epithelial Cycling cells
#
#                             organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# N175041_N1-ACTTGTTCATTGTGCA            NCBITaxon:9606            EFO:0009899
# N175041_N1-TCGAGGCCACGAAAGC            NCBITaxon:9606            EFO:0009899
# N175041_N1-CTCCTAGCACATTAGC            NCBITaxon:9606            EFO:0009899
# N175041_N1-CTCAGAACACGACGAA            NCBITaxon:9606            EFO:0009899
# N175041_N1-CTAGAGTTCACAAACC            NCBITaxon:9606            EFO:0009899
# ...                                               ...                    ...
# N104152_N-AGCAGCCTCCGAGCCA             NCBITaxon:9606            EFO:0009899
# N104152_N-TAGAGCTTCGGGAGTA             NCBITaxon:9606            EFO:0009899
# N104152_N-CTCATTAAGATGCCTT             NCBITaxon:9606            EFO:0009899
# N104152_N-TGAGAGGTCCACGTTC             NCBITaxon:9606            EFO:0009899
# N104152_N-AGGGTGAGTCTCTTTA             NCBITaxon:9606            EFO:0009899
#
#                             disease_ontology_term_id  ... tissue_type  \
# cell_id                                               ...
# N175041_N1-ACTTGTTCATTGTGCA            MONDO:0005011  ...      tissue
# N175041_N1-TCGAGGCCACGAAAGC            MONDO:0005011  ...      tissue
# N175041_N1-CTCCTAGCACATTAGC            MONDO:0005011  ...      tissue
# N175041_N1-CTCAGAACACGACGAA            MONDO:0005011  ...      tissue
# N175041_N1-CTAGAGTTCACAAACC            MONDO:0005011  ...      tissue
# ...                                              ...  ...         ...
# N104152_N-AGCAGCCTCCGAGCCA             MONDO:0005011  ...      tissue
# N104152_N-TAGAGCTTCGGGAGTA             MONDO:0005011  ...      tissue
# N104152_N-CTCATTAAGATGCCTT             MONDO:0005011  ...      tissue
# N104152_N-TGAGAGGTCCACGTTC             MONDO:0005011  ...      tissue
# N104152_N-AGGGTGAGTCTCTTTA             MONDO:0005011  ...      tissue
#
#                                    cell_type      assay        disease  \
# cell_id
# N175041_N1-ACTTGTTCATTGTGCA       enterocyte  10x 3' v2  Crohn disease
# N175041_N1-TCGAGGCCACGAAAGC       enterocyte  10x 3' v2  Crohn disease
# N175041_N1-CTCCTAGCACATTAGC       enterocyte  10x 3' v2  Crohn disease
# ...
# ...                                              ...  ...         ...
# N154787_L2-GTTACAGCATCGTGCG            MONDO:0005011  ...      tissue
# N154787_L2-GAACTGTAGAGCATAT            MONDO:0005011  ...      tissue
# N154787_L2-GTCACTCCATCCTATT            MONDO:0005011  ...      tissue
# N154787_L2-TAGCACAGTCGAACAG            MONDO:0005011  ...      tissue
# N154787_L2-TAGAGTCCACCACTGG            MONDO:0005011  ...      tissue
#
#                                    cell_type      assay        disease  \
# cell_id
# N154787_L1-TACTTGTTCCTTGACC  epithelial cell  10x 3' v3  Crohn disease
# N154787_L1-ATAGACCAGATTACCC       enterocyte  10x 3' v3  Crohn disease
# N154787_L1-TTTGGAGGTCATCACA      goblet cell  10x 3' v3  Crohn disease
# N154787_L1-AGGTTGTTCTACTATC       enterocyte  10x 3' v3  Crohn disease
# N154787_L1-AGACAGGTCCAACACA      goblet cell  10x 3' v3  Crohn disease
# ...                                      ...        ...            ...
# N154787_L2-GTTACAGCATCGTGCG  epithelial cell  10x 3' v3  Crohn disease
# N154787_L2-GAACTGTAGAGCATAT       enterocyte  10x 3' v3  Crohn disease
# N154787_L2-GTCACTCCATCCTATT       enterocyte  10x 3' v3  Crohn disease
# N154787_L2-TAGCACAGTCGAACAG       enterocyte  10x 3' v3  Crohn disease
# N154787_L2-TAGAGTCCACCACTGG       enterocyte  10x 3' v3  Crohn disease
#
#                                  organism   sex  tissue  \
# cell_id
# N154787_L1-TACTTGTTCCTTGACC  Homo sapiens  male  caecum
# N154787_L1-ATAGACCAGATTACCC  Homo sapiens  male  caecum
# N154787_L1-TTTGGAGGTCATCACA  Homo sapiens  male  caecum
# N154787_L1-AGGTTGTTCTACTATC  Homo sapiens  male  caecum
# N154787_L1-AGACAGGTCCAACACA  Homo sapiens  male  caecum
# ...                                   ...   ...     ...
# N154787_L2-GTTACAGCATCGTGCG  Homo sapiens  male  caecum
# N154787_L2-GAACTGTAGAGCATAT  Homo sapiens  male  caecum
# N154787_L2-GTCACTCCATCCTATT  Homo sapiens  male  caecum
# N154787_L2-TAGCACAGTCGAACAG  Homo sapiens  male  caecum
# N154787_L2-TAGAGTCCACCACTGG  Homo sapiens  male  caecum
#
#                             self_reported_ethnicity   development_stage  \
# cell_id
# N154787_L1-TACTTGTTCCTTGACC                 unknown  sixth decade stage
# N154787_L1-ATAGACCAGATTACCC                 unknown  sixth decade stage
# N154787_L1-TTTGGAGGTCATCACA                 unknown  sixth decade stage
# N154787_L1-AGGTTGTTCTACTATC                 unknown  sixth decade stage
# N154787_L1-AGACAGGTCCAACACA                 unknown  sixth decade stage
# ...                                             ...                 ...
# N154787_L2-GTTACAGCATCGTGCG                 unknown  sixth decade stage
# N154787_L2-GAACTGTAGAGCATAT                 unknown  sixth decade stage
# N154787_L2-GTCACTCCATCCTATT                 unknown  sixth decade stage
# N154787_L2-TAGCACAGTCGAACAG                 unknown  sixth decade stage
# N154787_L2-TAGAGTCCACCACTGG                 unknown  sixth decade stage
#
#                             observation_joinid
# cell_id
# N154787_L1-TACTTGTTCCTTGACC         0<|kNqMXlJ
# N154787_L1-ATAGACCAGATTACCC         <)dEh4@BvF
# N154787_L1-TTTGGAGGTCATCACA         xknmedWlKj
# N154787_L1-AGGTTGTTCTACTATC         t_rJ6z^>Z~
# N154787_L1-AGACAGGTCCAACACA         g{ZK|>Z(LJ
# ...                                        ...
# N154787_L2-GTTACAGCATCGTGCG         @-#0k@CjT|
# N154787_L2-GAACTGTAGAGCATAT         kd}@W8k)rL
# N154787_L2-GTCACTCCATCCTATT         %ege{e%k`>
# N154787_L2-TAGCACAGTCGAACAG         ?0uvtO*T|m
# N154787_L2-TAGAGTCCACCACTGG         FAHHdo_~cC
#
# [76 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['N154787_L1-TACTTGTTCCTTGACC', 'N154787_L1-ATAGACCAGATTACCC',
#        'N154787_L1-TTTGGAGGTCATCACA', 'N154787_L1-AGGTTGTTCTACTATC',
#        'N154787_L1-AGACAGGTCCAACACA', 'N154787_L1-CCGTTCAAGTGACACG',
#        'N154787_L1-TCATTGTAGAATCGCG', 'N154787_L1-TGTCCACTCAGGGATG',
#        'N154787_L1-ATTTCTGGTTCAATCG', 'N154787_L1-AAGCATCAGTCATGGG',
#        'N154787_L1-GATGGAGAGTCAGCCC', 'N154787_L1-TTCACCGAGGCCTGCT',
#        'N154787_L1-CTAGACAAGCGACATG', 'N154787_L1-ATCCGTCAGATACAGT',
#        'N154787_L1-GGGCCATAGTATGAGT', 'N154787_L1-CTGCTCAAGTCTACCA',
#        'N154787_L1-TCGCTCATCCTTCAGC', 'N154787_L1-CCTGCATTCACAGTGT',
#        'N154787_L1-TTAATCCCATCCCGTT', 'N154787_L1-AAGGTAAGTTCTGAGT',
#        'N154787_L1-AACCTGACAACACACT', 'N154787_L1-AGCTCAAGTTTACCTT',
#        'N154787_L1-ACTACGAGTATCTCGA', 'N154787_L1-ACGTACAAGCTCAGAG',
#        'N154787_L1-ACGGGTCCAAGGCCTC', 'N154787_L1-GTAACACTCGCACTCT',
#        'N154787_L1-TCCTGCAAGGGCTTCC', 'N154787_L1-TCGAACACACGTATAC',
#        'N154787_L1-AACCACATCCAGCCTT', 'N154787_L1-TGCTCCACAGACCTAT',
#        'N154787_L1-CCACGAGAGATCCCAT', 'N154787_L1-AACCCAATCCTCAGGG',
#        'N154787_L1-AGAAATGAGTCCCAAT', 'N154787_L1-AACCACATCACGTAGT',
#        'N154787_L1-GTTGAACGTGTTACTG', 'N154787_L1-TATACCTAGGAGAATG',
#        'N154787_L1-GTAATCGTCTCTCCGA', 'N154787_L1-CTCAGTCTCACCTGTC',
#        'N154787_L1-AATCGACAGTCGAGGT', 'N154787_L1-GATGAGGCAAACTGCT',
#        'N154787_L2-AAACCCACATCAGCAT', 'N154787_L2-GTCTACCGTTCCATTT',
#        'N154787_L2-GACAGCCCAATACGAA', 'N154787_L2-ATTCATCCAACAACAA',
#        'N154787_L2-TGTCCACAGAGCAGAA', 'N154787_L2-GTCTAGAAGAGTGGCT',
#        'N154787_L2-TCTACATAGAATCGAT', 'N154787_L2-GTCCCATTCTGGCTGG',
#        'N154787_L2-TCTCTGGTCTTCGACC', 'N154787_L2-GTTAGACCACAGTCGC',
#        'N154787_L2-TAAGTCGCAGGTGGAT', 'N154787_L2-TCCCACAAGGATTCAA',
#        'N154787_L2-GATCCCTTCTCGGCTT', 'N154787_L2-GCCAGCATCGTTCTAT',
#        'N154787_L2-ATCTCTATCCGTGGGT', 'N154787_L2-CAGGGCTTCAGCTAGT',
#        'N154787_L2-AAGCGTTTCCGGTAGC', 'N154787_L2-GAGCCTGGTTTGAAAG',
#        'N154787_L2-GTAAGTCCAGGAGGTT', 'N154787_L2-GAGTTGTTCACATCAG',
#        'N154787_L2-AAAGGTACATCTTCGC', 'N154787_L2-GTCATTTCAACCTATG',
#        'N154787_L2-CACAGGCAGATTGATG', 'N154787_L2-AAGACAAAGTTCTCTT',
#        'N154787_L2-AACGGGAAGGTGCCTC', 'N154787_L2-TTGATGGGTTGAGTCT',
#        'N154787_L2-GCGTTTCCAGTTGTTG', 'N154787_L2-TACTTACAGCGTGCTC',
#        'N154787_L2-GTTATGGTCACGACTA', 'N154787_L2-CCGCAAGTCAGCTAGT',
#        'N154787_L2-GTCTACCAGTGGACGT', 'N154787_L2-GTTACAGCATCGTGCG',
#        'N154787_L2-GAACTGTAGAGCATAT', 'N154787_L2-GTCACTCCATCCTATT',
#        'N154787_L2-TAGCACAGTCGAACAG', 'N154787_L2-TAGAGTCCACCACTGG'],
#       dtype='object', name='cell_id')
# Current memory usage: 6857.71 MB
# collecting 583 objects
# Current memory usage: 6857.71 MB
#
# Analyzing sample 9/9: right colon (Crohn disease)
# - Sample matrix has shape (2945, 27289)
# adata_sample.obs:                              biosample_id  n_genes  n_counts  Type donor_id  \
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC    N104689_N   5811.0   40067.0  NonI   104689
# N104689_N2-CTGTGCTTCATCACCC    N104689_N   5800.0   40040.0  NonI   104689
# N104689_N2-AGCTCCTAGCTGCGAA    N104689_N   5373.0   37058.0  NonI   104689
# N104689_N2-TGTGTTTGTCTCTCTG    N104689_N   5509.0   36819.0  NonI   104689
# N104689_N2-GGGTTGCTCGTAGGTT    N104689_N   4827.0   36352.0  NonI   104689
# ...                                  ...      ...       ...   ...      ...
# N104689_N2-CATGACATCCTATGTT    N104689_N    217.0     290.0  NonI   104689
# N104689_N2-TGATTTCCACAGGCCT    N104689_N    201.0     281.0  NonI   104689
# N104689_N2-TAAACCGGTGGCTCCA    N104689_N    211.0     274.0  NonI   104689
# N104689_N2-GAACCTATCGGAGGTA    N104689_N    200.0     271.0  NonI   104689
# N104689_N2-CCACGGATCCTACAGA    N104689_N    201.0     255.0  NonI   104689
#
#                             Layer                  Celltype  \
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-CTGTGCTTCATCACCC     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-AGCTCCTAGCTGCGAA     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-TGTGTTTGTCTCTCTG     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-GGGTTGCTCGTAGGTT     N     Stem cells OLFM4 LGR5
# ...                           ...                       ...
# N104689_N2-CATGACATCCTATGTT     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-TGATTTCCACAGGCCT     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-TAAACCGGTGGCTCCA     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-GAACCTATCGGAGGTA     N  Enterocytes CA1 CA2 CA4-
# N104689_N2-CCACGGATCCTACAGA     N  Enterocytes CA1 CA2 CA4-
#
#                             organism_ontology_term_id assay_ontology_term_id  \
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC            NCBITaxon:9606            EFO:0009899
# N104689_N2-CTGTGCTTCATCACCC            NCBITaxon:9606            EFO:0009899
# N104689_N2-AGCTCCTAGCTGCGAA            NCBITaxon:9606            EFO:0009899
# N104689_N2-TGTGTTTGTCTCTCTG            NCBITaxon:9606            EFO:0009899
# N104689_N2-GGGTTGCTCGTAGGTT            NCBITaxon:9606            EFO:0009899
# ...                                               ...                    ...
# N104689_N2-CATGACATCCTATGTT            NCBITaxon:9606            EFO:0009899
# N104689_N2-TGATTTCCACAGGCCT            NCBITaxon:9606            EFO:0009899
# N104689_N2-TAAACCGGTGGCTCCA            NCBITaxon:9606            EFO:0009899
# N104689_N2-GAACCTATCGGAGGTA            NCBITaxon:9606            EFO:0009899
# N104689_N2-CCACGGATCCTACAGA            NCBITaxon:9606            EFO:0009899
#
#                             disease_ontology_term_id  ... tissue_type  \
# cell_id                                               ...
# N104689_N2-TGAGAGGCACGGTGTC            MONDO:0005011  ...      tissue
# N104689_N2-CTGTGCTTCATCACCC            MONDO:0005011  ...      tissue
# N104689_N2-AGCTCCTAGCTGCGAA            MONDO:0005011  ...      tissue
# N104689_N2-TGTGTTTGTCTCTCTG            MONDO:0005011  ...      tissue
# N104689_N2-GGGTTGCTCGTAGGTT            MONDO:0005011  ...      tissue
# ...                                              ...  ...         ...
# N104689_N2-CATGACATCCTATGTT            MONDO:0005011  ...      tissue
# N104689_N2-TGATTTCCACAGGCCT            MONDO:0005011  ...      tissue
# N104689_N2-TAAACCGGTGGCTCCA            MONDO:0005011  ...      tissue
# N104689_N2-GAACCTATCGGAGGTA            MONDO:0005011  ...      tissue
# N104689_N2-CCACGGATCCTACAGA            MONDO:0005011  ...      tissue
#
#                               cell_type      assay        disease  \
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-CTGTGCTTCATCACCC  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-AGCTCCTAGCTGCGAA  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-TGTGTTTGTCTCTCTG  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-GGGTTGCTCGTAGGTT   stem cell  10x 3' v2  Crohn disease
# ...                                 ...        ...            ...
# N104689_N2-CATGACATCCTATGTT  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-TGATTTCCACAGGCCT  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-TAAACCGGTGGCTCCA  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-GAACCTATCGGAGGTA  enterocyte  10x 3' v2  Crohn disease
# N104689_N2-CCACGGATCCTACAGA  enterocyte  10x 3' v2  Crohn disease
#
#                                  organism   sex       tissue  \
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC  Homo sapiens  male  right colon
# N104689_N2-CTGTGCTTCATCACCC  Homo sapiens  male  right colon
# N104689_N2-AGCTCCTAGCTGCGAA  Homo sapiens  male  right colon
# N104689_N2-TGTGTTTGTCTCTCTG  Homo sapiens  male  right colon
# N104689_N2-GGGTTGCTCGTAGGTT  Homo sapiens  male  right colon
# ...                                   ...   ...          ...
# N104689_N2-CATGACATCCTATGTT  Homo sapiens  male  right colon
# N104689_N2-TGATTTCCACAGGCCT  Homo sapiens  male  right colon
# N104689_N2-TAAACCGGTGGCTCCA  Homo sapiens  male  right colon
# N104689_N2-GAACCTATCGGAGGTA  Homo sapiens  male  right colon
# N104689_N2-CCACGGATCCTACAGA  Homo sapiens  male  right colon
#
#                             self_reported_ethnicity   development_stage  \
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC                 unknown  third decade stage
# N104689_N2-CTGTGCTTCATCACCC                 unknown  third decade stage
# N104689_N2-AGCTCCTAGCTGCGAA                 unknown  third decade stage
# N104689_N2-TGTGTTTGTCTCTCTG                 unknown  third decade stage
# N104689_N2-GGGTTGCTCGTAGGTT                 unknown  third decade stage
# ...                                             ...                 ...
# N104689_N2-CATGACATCCTATGTT                 unknown  third decade stage
# N104689_N2-TGATTTCCACAGGCCT                 unknown  third decade stage
# N104689_N2-TAAACCGGTGGCTCCA                 unknown  third decade stage
# N104689_N2-GAACCTATCGGAGGTA                 unknown  third decade stage
# N104689_N2-CCACGGATCCTACAGA                 unknown  third decade stage
#
#                             observation_joinid
# cell_id
# N104689_N2-TGAGAGGCACGGTGTC         `+Q>Ix=?M|
# N104689_N2-CTGTGCTTCATCACCC         M^EMYYJ>Pk
# N104689_N2-AGCTCCTAGCTGCGAA         +yE~RFMkaD
# N104689_N2-TGTGTTTGTCTCTCTG         OHciihzVGx
# N104689_N2-GGGTTGCTCGTAGGTT         f%}rR%DQ}x
# ...                                        ...
# N104689_N2-CATGACATCCTATGTT         hG5ywtAAx?
# N104689_N2-TGATTTCCACAGGCCT         l(k7d0F#eL
# N104689_N2-TAAACCGGTGGCTCCA         AQHN*^khu#
# N104689_N2-GAACCTATCGGAGGTA         7_EBAhhAs-
# N104689_N2-CCACGGATCCTACAGA         WkUm0dTc7v
#
# [2945 rows x 28 columns]
# adata_sample.var[feature_name]:  ENSG00000228463    ENSG00000228463.10
# ENSG00000237094    ENSG00000237094.13
# ENSG00000228327     ENSG00000228327.6
# ENSG00000237491             LINC01409
# ENSG00000177757                FAM87B
#                           ...
# ENSG00000237832     ENSG00000237832.1
# ENSG00000268287     ENSG00000268287.1
# ENSG00000254760          SIGLEC10-AS2
# ENSG00000268316     ENSG00000268316.1
# ENSG00000223726     ENSG00000223726.1
# Name: feature_name, Length: 27289, dtype: category
# Categories (27289, object): ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', ..., 'ZYG11B', 'ZYX', 'ZZEF1', 'ZZZ3']
# adata_sample.obs[Celltype]:  Index(['N104689_N2-TGAGAGGCACGGTGTC', 'N104689_N2-CTGTGCTTCATCACCC',
#        'N104689_N2-AGCTCCTAGCTGCGAA', 'N104689_N2-TGTGTTTGTCTCTCTG',
#        'N104689_N2-GGGTTGCTCGTAGGTT', 'N104689_N2-ATTGGACCAGTCCTTC',
#        'N104689_N2-CCTCTGACATCTACGA', 'N104689_N2-GGAGCAACACGGTAGA',
#        'N104689_N2-GTGCGGTGTCGCGGTT', 'N104689_N2-TACCTTATCAACCATG',
#        ...
#        'N104689_N2-GTTACAGGTATTCTCT', 'N104689_N2-AGTGAGGGTAGAGTGC',
#        'N104689_N2-AATCCAGTCATTGCGA', 'N104689_N2-CAGCCGATCGGCCGAT',
#        'N104689_N2-AGCGGTCTCACTCCTG', 'N104689_N2-CATGACATCCTATGTT',
#        'N104689_N2-TGATTTCCACAGGCCT', 'N104689_N2-TAAACCGGTGGCTCCA',
#        'N104689_N2-GAACCTATCGGAGGTA', 'N104689_N2-CCACGGATCCTACAGA'],
#       dtype='object', name='cell_id', length=2945)
# Current memory usage: 7096.24 MB
# collecting 581 objects
# Current memory usage: 7096.24 MB

# %%
# load json data
with open("unique_celltypes_per_dataset.json", "r") as f:
    unique_cell_types_per_dataset = json.load(f)
# get a list of unique cell type over entries
unique_cell_types = set()
for dataset, cell_types in unique_cell_types_per_dataset.items():
    unique_cell_types.update(cell_types)

# %%
for item in unique_cell_types:
    print(item)
# Out:
# Stem cells OLFM4
# Paneth cells
# Goblet cells SPINK4
# Goblet cells MUC2 TFF1
# Tuft cells
# Epithelial Cycling cells
# Stem cells OLFM4 PCNA
# Stem cells OLFM4 LGR5
# Enterocytes BEST4
# Enterocytes TMIGD1 MEP1A
# Enteroendocrine cells
# Enterocytes CA1 CA2 CA4-
# Goblet cells MUC2 TFF1-

# %%
# test = {
#     "Enterocytes BEST4": {
#         BEST4, OTOP2, CA7, GUCA2A, GUCA2B, SPIB, CFTR # with region-specific additions like CFTR in the small intestine and OTOP2 in the colon.
#     },
#     "Goblet cells MUC2 TFF1":
#         {
#             MUC2, TFF1, TFF3, FCGBP, AGR2, SPDEF
#         }
    
#     "Tuft cells": {
#     POU2F3, DCLK1
#     }

#     "Goblet cells SPINK4": {
#         MUC2, SPINK4
#     }
#     "Enterocytes TMIGD1 MEP1A": {
#     CA1, CA2, TMIGD1, MEP1A
#     }
#     "Enterocytes CA1 CA2 CA4-": {
#         CA1, CA2
#     }
#     Goblet cells MUC2 TFF1-: MUC2
#     Epithelial Cycling cells: LGR5, OLFM4, MKI67
#     Enteroendocrine cells: CHGA, GCG, GIP, CCK
#     Stem cells OLFM4: OLFM4, LGR5
#     Paneth cells: LYZ, DEFA5
#         "Stem cells OLFM4 LGR5": {
#     OLFM4, LGR5, and Ascl2
#     }
        
#         Stem cells OLFM4 PCNA {
#         OLFM4 and PCNA
#         LGR5, Ascl2, SOX9, and TERT}
# }

# %%
marker_genes = {
  "Enterocytes BEST4": [
    "BEST4",
    "OTOP2",
    "CA7",
    "GUCA2A",
    "GUCA2B",
    "SPIB",
    "CFTR"
  ],
  "Goblet cells MUC2 TFF1": [
    "MUC2",
    "TFF1",
    "TFF3",
    "FCGBP",
    "AGR2",
    "SPDEF"
  ],
  "Tuft cells": [
    "POU2F3",
    "DCLK1"
  ],
  "Goblet cells SPINK4": [
    "MUC2",
    "SPINK4"
  ],
  "Enterocytes TMIGD1 MEP1A": [
    "CA1",
    "CA2",
    "TMIGD1",
    "MEP1A"
  ],
  "Enterocytes CA1 CA2 CA4-": [
    "CA1",
    "CA2"
  ],
  "Goblet cells MUC2 TFF1-": [
    "MUC2"
  ],
  "Epithelial Cycling cells": [
    "LGR5",
    "OLFM4",
    "MKI67"
  ],
  "Enteroendocrine cells": [
    "CHGA",
    "GCG",
    "GIP",
    "CCK"
  ],
  "Stem cells OLFM4": [
    "OLFM4",
    "LGR5"
  ],
  "Stem cells OLFM4 LGR5": [
    "OLFM4",
    "LGR5",
    "ASCL2"
  ],
  "Stem cells OLFM4 PCNA": [
    "OLFM4",
    "PCNA",
    "LGR5",
    "ASCL2",
    "SOX9",
    "TERT"
  ],
  "Paneth cells": [
    "LYZ",
    "DEFA5"
  ]
}


import os
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from anndata import read_h5ad

methods = [
    "MAGIC",
    "SAUCIE"
]


def expand_magic_matrix(y, reduced_matrix):
    expanded = np.zeros(y.shape)
    
    nonzero_counts = (y != 0).sum(axis=0)
    kept_columns = np.where(nonzero_counts >= 5)[0]
    removed_columns = np.where(nonzero_counts < 5)[0]
    
    # Copy values from reduced matrix to their original positions
    for j_reduced, j_original in enumerate(kept_columns):
        expanded[:, j_original] = reduced_matrix[:, j_reduced]
        
    for _, j_original in enumerate(removed_columns):
        expanded[:, j_original] = y[:, j_original]
    
    return expanded

data_dir = Path("./datasets")
files = list(data_dir.glob("*.h5ad"))

output_dir = Path("output/barplots")
output_dir.mkdir(exist_ok=True, parents=True)

for f in files:
    print(f"Processing dataset {f.stem}")
    adata = read_h5ad(f)
    
    # Filter out non-primary data if needed
    adata = adata[adata.obs["is_primary_data"] == True]
    
    # -------------------------------------------------------
    # 1) Overwrite the var_names with "feature_name" so we can match gene symbols
    #    We'll also strip off trailing version suffixes like ".1", ".10" if present
    # -------------------------------------------------------
    if "feature_name" in adata.var.columns:
        # Convert to string, strip trailing version number if they exist
        adata.var_names = adata.var["feature_name"].astype(str).str.replace(r"\.\d+$", "", regex=True)
    else:
        print("Warning: 'feature_name' not found in adata.var.columns. Gene symbol matching may fail.")
    
    # We'll gather the sample-level splits by "disease" and "tissue"
    metadata_markers = adata.obs[["disease", "tissue"]].drop_duplicates()
    
    # For each subset, do the analysis
    for idx, (disease, tissue) in metadata_markers.iterrows():
        mask = (adata.obs["disease"] == disease) & (adata.obs["tissue"] == tissue)
        adata_sample = adata[mask]
        
        # The original expression matrix (before imputation)
        X_original = adata_sample.X.toarray()  # shape: nCells x nGenes
        
        # 'obs_celltype' is the cell-type labeling in this subset
        obs_celltype = adata_sample.obs["Celltype"]
        
        print(f"  Analyzing subset: {tissue} ({disease}), shape={X_original.shape}")
        
        # For each cell type in marker_genes, check if that celltype is present
        # (exact or partial match in obs_celltype)
        for ctype_key, ref_genes in marker_genes.items():
            
            # We'll do exact matching here:
            matching_mask = (obs_celltype == ctype_key)
            n_cells = np.sum(matching_mask)
            
            if n_cells < 5:
                print(f"    [Skipping: too few cells of type {ctype_key} ({n_cells} cells)]")
                continue
            
            print(f"    Celltype={ctype_key}, #cells={n_cells}")
            
            # Subset to just those cells
            adata_ct = adata_sample[matching_mask]
            X_ct_original = adata_ct.X.toarray()  # shape: n_cells_of_ctype x nGenes
            var_names_ct = adata_ct.var_names     # Now these are the gene symbols after our overwrite
            
            # For each reference gene in that cell type, do the co-occurrence analysis
            for ref_gene in ref_genes:
                if ref_gene not in var_names_ct:
                    # skip if the gene is not found
                    print(f"      [Skipping: {ref_gene} not found in cell type {ctype_key}]")
                    continue
                
                # Get the column index of this reference gene
                y_idx = var_names_ct.get_loc(ref_gene)  # integer index in var_names_ct
                
                # For each imputation method, load the imputed matrix and analyze
                for method_name in methods:
                    imputed_path = Path("output") / method_name / f"{f.stem}" / disease / (tissue + ".npy")
                    if not imputed_path.exists():
                        print(f"      [Skipping: no imputed data for {method_name}]")
                        continue
                        
                    X_ct_imputed = np.load(imputed_path)  # shape should match X_ct_original
                    
                    if method_name == "MAGIC":
                      X_ct_imputed = expand_magic_matrix(X_original, X_ct_imputed)
                    if X_ct_imputed.shape != X_ct_original.shape:
                        print(f"      [Warning: shape mismatch for {method_name}]")
                        continue
                    
                    # 1) Identify which cells express Y after imputation
                    y_expr_imputed = X_ct_imputed[:, y_idx]
                    y_positive_imputed = (y_expr_imputed > 0)
                    
                    # skip if few or none express Y
                    n_ypos = y_positive_imputed.sum()
                    if n_ypos < 5:
                        print(f"      [Skipping: too few Y+ cells ({n_ypos}) for {ref_gene}]")
                        continue
                    
                    # 2) Among Y+ cells, count how many express each gene
                    coexpr_counts = np.sum(X_ct_imputed[y_positive_imputed, :] > 0, axis=0)
                    coexpr_fraction = coexpr_counts / n_ypos
                    
                    # 3) Sort descending to pick top 10
                    topN = 10
                    top_indices = np.argsort(coexpr_fraction)[::-1][:topN]
                    top_genes = var_names_ct[top_indices]
                    
                    # Fractions AFTER imputation (all Y+ cells):
                    coexpr_counts_after = coexpr_counts[top_indices]
                    frac_after = coexpr_counts_after / n_ypos
                    
                    # 4) Fractions BEFORE imputation
                    y_expr_before = X_ct_original[:, y_idx]
                    y_positive_before = (y_expr_before > 0)
                    n_ypos_before = y_positive_before.sum()
                    
                    frac_before_list = []
                    for gidx in top_indices:
                        both_mask = (y_positive_before & (X_ct_original[:, gidx] > 0))
                        frac_before_list.append(both_mask.sum() / (n_ypos_before + 1e-9))
                    frac_before = np.array(frac_before_list)
                    
                    # 5) Fractions among cells that had Y=0 and got imputed to Y>0
                    y_zero2nonzero = ((y_expr_before == 0) & (y_expr_imputed > 0))
                    n_y_zero2nonzero = y_zero2nonzero.sum()
                    
                    frac_zero2nonzero_list = []
                    for gidx in top_indices:
                        both_mask = (y_zero2nonzero & (X_ct_imputed[:, gidx] > 0))
                        frac_zero2nonzero_list.append(both_mask.sum() / (n_y_zero2nonzero + 1e-9))
                    frac_zero2nonzero = np.array(frac_zero2nonzero_list)
                    
                    # 6) Plot the bar chart with 3 bars per gene
                    x = np.arange(len(top_genes))  # e.g. 0..9
                    width = 0.25
                    fig, ax = plt.subplots(figsize=(8, 4))
                    ax.bar(x - width, frac_before, width, label='Before')
                    ax.bar(x,         frac_after,  width, label='After')
                    ax.bar(x + width, frac_zero2nonzero, width, label='Y=0→non0')
                    
                    ax.set_xticks(x)
                    ax.set_xticklabels(top_genes, rotation=90)
                    ax.set_ylabel("Fraction of Y+ cells also expressing gene")
                    ax.set_title(
                        f"{f.stem}\n{disease}, {tissue}\nCelltype={ctype_key}, Ref={ref_gene}, Method={method_name}"
                    )
                    ax.legend()
                    plt.tight_layout()
                    
                    # 7) Save figure
                    plot_out = output_dir / f"{f.stem}_{disease}_{tissue}_{ctype_key}_{ref_gene}_{method_name}.png"
                    print(f"      Saving plot to {plot_out}")
                    plt.savefig(plot_out, dpi=120)
                    plt.close()
        
        print()  # blank line for readability
# Out:
# Processing dataset 63ff2c52-cb63-44f0-bac3-d0b33373e312
#   Analyzing subset: lamina propria of mucosa of colon (Crohn disease), shape=(8076, 27289)
#     Celltype=Enterocytes BEST4, #cells=130
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#     Celltype=Goblet cells MUC2 TFF1, #cells=185
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Skipping: FCGBP not found in cell type Goblet cells MUC2 TFF1]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#     Celltype=Tuft cells, #cells=76
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#     Celltype=Goblet cells SPINK4, #cells=29
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#     Celltype=Enterocytes TMIGD1 MEP1A, #cells=1503
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#       [Warning: shape mismatch for MAGIC]
#       [Warning: shape mismatch for SAUCIE]
#     Celltype=Enterocytes CA1 CA2 CA4-, #cells=2555
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 182
#     179 X_ct_imputed = np.load(imputed_path)  # shape should match X_ct_original
#     181 if method_name == "MAGIC":
# --> 182   X_ct_imputed = expand_magic_matrix(X_original, X_ct_imputed)
#     183 if X_ct_imputed.shape != X_ct_original.shape:
#     184     print(f"      [Warning: shape mismatch for {method_name}]")
#
# Cell In[12], line 100, in expand_magic_matrix(y, reduced_matrix)
#      97     expanded[:, j_original] = reduced_matrix[:, j_reduced]
#      99 for _, j_original in enumerate(removed_columns):
# --> 100     expanded[:, j_original] = y[:, j_original]
#     102 return expanded
#
# KeyboardInterrupt:

# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from anndata import read_h5ad

# ----------------- MARKER GENES DICTIONARY -----------------
marker_genes = {
  "Enterocytes BEST4": [
    "BEST4", "OTOP2", "CA7", "GUCA2A", "GUCA2B", "SPIB", "CFTR"
  ],
  "Goblet cells MUC2 TFF1": [
    "MUC2", "TFF1", "TFF3", "FCGBP", "AGR2", "SPDEF"
  ],
  "Tuft cells": [
    "POU2F3", "DCLK1"
  ],
  "Goblet cells SPINK4": [
    "MUC2", "SPINK4"
  ],
  "Enterocytes TMIGD1 MEP1A": [
    "CA1", "CA2", "TMIGD1", "MEP1A"
  ],
  "Enterocytes CA1 CA2 CA4-": [
    "CA1", "CA2"
  ],
  "Goblet cells MUC2 TFF1-": [
    "MUC2"
  ],
  "Epithelial Cycling cells": [
    "LGR5", "OLFM4", "MKI67"
  ],
  "Enteroendocrine cells": [
    "CHGA", "GCG", "GIP", "CCK"
  ],
  "Stem cells OLFM4": [
    "OLFM4", "LGR5"
  ],
  "Stem cells OLFM4 LGR5": [
    "OLFM4", "LGR5", "ASCL2"
  ],
  "Stem cells OLFM4 PCNA": [
    "OLFM4", "PCNA", "LGR5", "ASCL2", "SOX9", "TERT"
  ],
  "Paneth cells": [
    "LYZ", "DEFA5"
  ]
}

# The imputation methods you want to compare
methods = ["MAGIC", "SAUCIE"]


def expand_magic_matrix(original_matrix, magic_imputed):
    """
    If your MAGIC pipeline removed columns for rare genes,
    this function re-inserts them. Otherwise, you can skip it.
    """
    expanded = np.zeros_like(original_matrix)
    nonzero_counts = (original_matrix != 0).sum(axis=0)
    kept_columns = np.where(nonzero_counts >= 5)[0]
    removed_columns = np.where(nonzero_counts < 5)[0]

    # Place the imputed columns back in the original positions
    for j_reduced, j_original in enumerate(kept_columns):
        expanded[:, j_original] = magic_imputed[:, j_reduced]

    # For columns that MAGIC removed, keep original counts
    for j_original in removed_columns:
        expanded[:, j_original] = original_matrix[:, j_original]

    return expanded


# We'll build one big DataFrame with columns=methods, and rows=(dataset, disease, tissue, celltype, gene)
# The cell values = fraction of cells that express that gene after imputation.

# Create an empty list to store row records
rows_list = []

data_dir = Path("./datasets")
files = list(data_dir.glob("*.h5ad"))

for f in files:
    dataset_id = f.stem
    print(f"Processing dataset {dataset_id}")
    adata = read_h5ad(f)

    # Filter out non-primary data if needed
    if "is_primary_data" in adata.obs.columns:
        adata = adata[adata.obs["is_primary_data"] == True]

    # Overwrite var_names with gene symbols from feature_name (strip version suffix)
    if "feature_name" in adata.var.columns:
        adata.var_names = adata.var["feature_name"].astype(str).str.replace(r"\.\d+$", "", regex=True)
    else:
        print("Warning: 'feature_name' not found in adata.var.columns. Gene symbol matching may fail.")

    # We'll gather the sample-level splits by "disease" and "tissue"
    # If your data doesn't have these columns, adapt accordingly
    if not {"disease", "tissue"}.issubset(adata.obs.columns):
        # If missing, we skip or just treat the entire dataset as one subset
        disease_tissue_df = pd.DataFrame([("Unknown", "Unknown")], columns=["disease", "tissue"])
    else:
        disease_tissue_df = adata.obs[["disease", "tissue"]].drop_duplicates()

    for _, (disease, tissue) in disease_tissue_df.iterrows():
        # Subset the AnnData
        mask = (adata.obs["disease"] == disease) & (adata.obs["tissue"] == tissue)
        adata_sample = adata[mask]

        if adata_sample.n_obs < 5:
            # skip if too few cells in that subset
            continue

        X_original = adata_sample.X.toarray()  # shape: nCells x nGenes
        obs_celltype = adata_sample.obs["Celltype"] if "Celltype" in adata_sample.obs.columns else None

        # If no "Celltype" col, skip or handle differently
        if obs_celltype is None:
            continue

        # For each known cell type in our marker_genes:
        for ctype_key, gene_list in marker_genes.items():
            # Subset to cells of this type
            matching_mask = (obs_celltype == ctype_key)
            n_cells_type = matching_mask.sum()
            if n_cells_type < 5:
                # skip
                continue

            adata_ct = adata_sample[matching_mask]
            X_ct_original = adata_ct.X.toarray()  # shape: (n_cells_of_type, nGenes)
            var_names_ct = adata_ct.var_names

            # For each gene in the marker list:
            for gene in gene_list:
                if gene not in var_names_ct:
                    # That gene doesn't exist in the final data
                    # We'll record fraction=0 or NaN to indicate missing
                    row_dict = {
                        "dataset": dataset_id,
                        "disease": disease,
                        "tissue": tissue,
                        "cell_type": ctype_key,
                        "gene": gene
                    }
                    # Put np.nan for each method
                    for m in methods:
                        row_dict[m] = np.nan
                    rows_list.append(row_dict)
                    continue

                gene_idx = var_names_ct.get_loc(gene)

                # For each method, load the imputed matrix & compute fraction
                row_dict = {
                    "dataset": dataset_id,
                    "disease": disease,
                    "tissue": tissue,
                    "cell_type": ctype_key,
                    "gene": gene
                }

                for m in methods:
                    imputed_path = Path("output") / m / dataset_id / disease / (tissue + ".npy")
                    if not imputed_path.exists():
                        # no data => store NaN
                        row_dict[m] = np.nan
                        continue

                    X_imputed_subset = np.load(imputed_path)
                    # If method=MAGIC, might need to expand columns
                    if m == "MAGIC":
                        X_imputed_subset = expand_magic_matrix(X_ct_original, X_imputed_subset)

                    # Check shape
                    if X_imputed_subset.shape != X_ct_original.shape:
                        print(f"[Warning: shape mismatch for {m}, skipping.]")
                        row_dict[m] = np.nan
                        continue

                    # fraction of cells that express the gene after imputation
                    expr_values = X_imputed_subset[:, gene_idx]
                    fraction_expr = np.mean(expr_values > 0)
                    row_dict[m] = fraction_expr

                # Add this row to our records
                rows_list.append(row_dict)

# ------------------- Build the final DataFrame ---------------------
df_recovery = pd.DataFrame(rows_list)
# Columns: [dataset, disease, tissue, cell_type, gene, MAGIC, SAUCIE, ...]

# Save as CSV
df_recovery.to_csv("marker_gene_recovery.csv", index=False)
print("Saved marker gene recovery fractions to 'marker_gene_recovery.csv'.")


# ------------------- OPTIONAL: Create Heatmaps ---------------------
# Because we have multiple datasets, diseases, tissues, & cell types, the DataFrame can be big.
# You may want to pivot & plot a separate heatmap for each dataset or each (disease,tissue).

# Example: pivot for a single dataset
unique_datasets = df_recovery["dataset"].unique()
for ds in unique_datasets:
    df_ds = df_recovery[df_recovery["dataset"] == ds]
    # Also might want to pick one disease/tissue or combine them
    # Let's do a demonstration of a pivot just by (cell_type, gene) as rows, methods as columns
    # We'll do an average across all disease/tissue for that dataset:

    # group by (cell_type, gene) and take the average across all subsets
    df_agg = df_ds.groupby(["cell_type", "gene"])[methods].mean().reset_index()

    # pivot => index=(cell_type,gene), columns=method, values= fraction
    df_pivot = df_agg.pivot(index=["cell_type", "gene"], columns=None)  # We'll flatten columns next

    # Because we have multiple methods => we'll get a multi-index
    # we can rearrange manually or do a separate pivot for each method
    # simpler approach: just do a pivot_table for each method individually

    # We'll do a single heatmap in a wide format: rows=(cell_type,gene), columns=method
    # so let's do a pivot_table with index=(cell_type,gene) and columns=method
    # value = fraction
    df_pivot = df_agg.pivot_table(index=["cell_type", "gene"], values=methods)

    # This yields a DataFrame with row index=(cell_type,gene), columns=[MAGIC, SAUCIE, ...]
    # Then we can make a heatmap:
    plt.figure(figsize=(10, 0.5*len(df_pivot) + 3))
    sns.heatmap(
        df_pivot, 
        annot=True, 
        fmt=".2f", 
        cmap="Blues",
        cbar_kws={"label": "Fraction Expressed (After Imputation)"}
    )
    plt.title(f"Marker Recovery: {ds} (avg across all disease/tissue)")
    plt.tight_layout()
    plt.savefig(f"marker_recovery_{ds}.png")
    plt.close()

print("Done creating optional heatmaps. See marker_recovery_<dataset>.png files.")
# Out:
# Processing dataset 63ff2c52-cb63-44f0-bac3-d0b33373e312
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
